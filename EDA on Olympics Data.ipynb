# %% [markdown]
# # Exploratory Data Analysis on Olympics Data (1896 to 2016)

# %% [markdown]
# ## Importing required libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pd.options.display.max_rows=10

# %% [markdown]
# ## Loading our datasets:

# %%
data=pd.read_csv("C:\\Users\\Venkatesan Murugesan\\Dropbox\\PC\\Desktop\\Project\\dataset\\athlete_events.csv")
country=pd.read_csv("C:\\Users\\Venkatesan Murugesan\\Dropbox\\PC\\Desktop\\Project\\dataset\\country_definitions.csv")

# %%
#see loaded data
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %% [raw]
# Column Details:
# ID - Unique number for each athlete
# Name - Athlete's name
# Sex - M or F
# Age - Integer
# Height - In centimeters
# Weight - In kilograms
# Team - Team name
# NOC - National Olympic Committee 3-letter code
# Games - Year and season
# Year - Integer
# Season - Summer or Winter
# City - Host city
# Sport - Sport
# Event - Event
# Medal - Gold, Silver, Bronze, or NA

# %% [markdown]
# ## Preprocessing:

# %%
#checking for duplicates (no of duplicated rows)
data.duplicated().sum()
# Out:
# 1385

# %%
#dulpicate rows in data
data[data.duplicated()]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 1252       704                   Dsir Antoine Acket   M  27.0     NaN     NaN
# 4282      2449               William Truman Aldrich   M  48.0     NaN     NaN
# 4283      2449               William Truman Aldrich   M  48.0     NaN     NaN
# 4862      2777               Hermann Reinhard Alker   M  43.0     NaN     NaN
# 4864      2777               Hermann Reinhard Alker   M  43.0     NaN     NaN
# ...        ...                                  ...  ..   ...     ...     ...
# 269994  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269995  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269997  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269999  135073   Doris Clare Zinkeisen (-Johnstone)   F  49.0     NaN     NaN
# 270200  135173                     Henri Achille Zo   M  58.0     NaN     NaN
#
# ...

# %%
#checking whether that is duplicate or not
data[data.ID==704]
# Out:
#        ID                Name Sex   Age  Height  Weight     Team  NOC  \
# 1251  704  Dsir Antoine Acket   M  27.0     NaN     NaN  Belgium  BEL
# 1252  704  Dsir Antoine Acket   M  27.0     NaN     NaN  Belgium  BEL
#
#             Games  Year  Season         City             Sport  \
# 1251  1932 Summer  1932  Summer  Los Angeles  Art Competitions
# 1252  1932 Summer  1932  Summer  Los Angeles  Art Competitions
#
#                                                Event Medal
# 1251  Art Competitions Mixed Painting, Unknown Event   NaN
# 1252  Art Competitions Mixed Painting, Unknown Event   NaN

# %%
#dropping duplicates from data
data.drop_duplicates(inplace=True)
#data after removing duplicates
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#take a look into column information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269731 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      269731 non-null  int64
#  1   Name    269731 non-null  object
#  2   Sex     269731 non-null  object
#  3   Age     260416 non-null  float64
#  4   Height  210917 non-null  float64
#  5   Weight  208204 non-null  float64
#  6   Team    269731 non-null  object
#  7   NOC     269731 non-null  object
#  8   Games   269731 non-null  object
#  9   Year    269731 non-null  int64
#  10  Season  269731 non-null  object
#  11  City    269731 non-null  object
#  12  Sport   269731 non-null  object
#  13  Event   269731 non-null  object
#  14  Medal   39772 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 32.9+ MB

# %%
#see unique values in columns
data.nunique()
# Out:
# ID        135571
# Name      134732
# Sex            2
# Age           74
# Height        95
#            ...
# Season         2
# City          42
# Sport         66
# Event        765
# Medal          3
# Length: 15, dtype: int64

# %%
#checking null values in data
data.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9315
# Height     58814
#            ...
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229959
# Length: 15, dtype: int64

# %%
#in percentage
(data.isna().sum())/(len(data))*100
# Out:
# ID         0.000000
# Name       0.000000
# Sex        0.000000
# Age        3.453441
# Height    21.804687
#             ...
# Season     0.000000
# City       0.000000
# Sport      0.000000
# Event      0.000000
# Medal     85.254939
# Length: 15, dtype: float64

# %%
#see descriptive analysis
data.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  269731.000000  260416.000000  210917.000000  208204.000000
# mean    68264.949591      25.454776     175.338953      70.701778
# std     39026.253843       6.163869      10.518507      14.349027
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34655.500000      21.000000     168.000000      60.000000
# 50%     68233.000000      24.000000     175.000000      70.000000
# 75%    102111.000000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  269731.000000
# mean     1978.623073
# std        29.752055
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
#filling NaN's with mean value
data.Age.fillna(round(data.Age.mean(),0),inplace=True)
data.Height.fillna(round(data.Height.mean(),0),inplace=True)
data.Weight.fillna(round(data.Weight.mean(),0),inplace=True)
#data wihtout null values
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0   175.0    71.0
# 3            4      Edgar Lindenau Aabye   M  34.0   175.0    71.0
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#now check isnull funtion
data.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age            0
# Height         0
#            ...
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229959
# Length: 15, dtype: int64

# %%
#lets see country data
country
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
#checking nulls on country data
country.isnull().sum()
# Out:
# NOC         0
# region      3
# notes     209
# dtype: int64

# %%
#checking nulls on region column
country[country.region.isnull().values]
# Out:
#      NOC region                 notes
# 168  ROT    NaN  Refugee Olympic Team
# 208  TUV    NaN                Tuvalu
# 213  UNK    NaN               Unknown

# %%
#taking those indexes to replace region with notes
x=country[pd.isna(country.region)].index
#changing the na's
for i in x:
    country.region[i]=country.notes[i]

# %%
#now see country data
country
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
#checking nulls again
country.isna().sum()
# Out:
# NOC         0
# region      0
# notes     209
# dtype: int64

# %%
#merging both datasets
data=data.merge(country,how='outer',on='NOC')
#remove unnecessary column
data.drop('notes',axis=1,inplace=True)
#renaming region column
data=data.rename(columns={'region':'Country'})
#now take a look on dataset
data
# Out:
#             ID                Name Sex   Age  Height  Weight     Team  NOC  \
# 0            1           A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1            2            A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2          602       Abudoureheman   M  22.0   182.0    75.0    China  CHN
# 3         1463           Ai Linuer   M  25.0   160.0    62.0    China  CHN
# 4         1464           Ai Yanhan   F  14.0   168.0    54.0    China  CHN
# ...        ...                 ...  ..   ...     ...     ...      ...  ...
# 269726  120575     Mamorallo Tjoka   F  23.0   150.0    56.0  Lesotho  LES
# 269727  120575     Mamorallo Tjoka   F  27.0   150.0    56.0  Lesotho  LES
# 269728  122166  M'apotlaki Ts'elho   F  15.0   175.0    71.0  Lesotho  LES
# 269729  122215          Lefa Tsapi   M  23.0   170.0    63.0  Lesotho  LES
# 269730  122299       Mosolesa Tsie   M  20.0   175.0    75.0  Lesotho  LES
#
#               Games  Year  Season            City       Sport  \
# ...

# %%
#player id is unique for every player so we can set it as index to make dataset easy
data.set_index('ID',inplace=True)
#now see the data
data
# Out:
#                       Name Sex   Age  Height  Weight     Team  NOC  \
# ID
# 1                A Dijiang   M  24.0   180.0    80.0    China  CHN
# 2                 A Lamusi   M  23.0   170.0    60.0    China  CHN
# 602          Abudoureheman   M  22.0   182.0    75.0    China  CHN
# 1463             Ai Linuer   M  25.0   160.0    62.0    China  CHN
# 1464             Ai Yanhan   F  14.0   168.0    54.0    China  CHN
# ...                    ...  ..   ...     ...     ...      ...  ...
# 120575     Mamorallo Tjoka   F  23.0   150.0    56.0  Lesotho  LES
# 120575     Mamorallo Tjoka   F  27.0   150.0    56.0  Lesotho  LES
# 122166  M'apotlaki Ts'elho   F  15.0   175.0    71.0  Lesotho  LES
# 122215          Lefa Tsapi   M  23.0   170.0    63.0  Lesotho  LES
# 122299       Mosolesa Tsie   M  20.0   175.0    75.0  Lesotho  LES
#
#               Games  Year  Season            City       Sport  \
# ID
# 1       1992 Summer  1992  Summer       Barcelona  Basketball
# ...

# %%
#team name and country name is not same in some rows. they are,
data[data.Team!=data.Country].head()
#so in this analysis country column taken into consideration
# Out:
#             Name Sex   Age  Height  Weight     Team  NOC        Games  Year  \
# ID
# 17299    Cai Yun   M  24.0   181.0    68.0  China-2  CHN  2004 Summer  2004
# 17299    Cai Yun   M  28.0   181.0    68.0  China-1  CHN  2008 Summer  2008
# 17299    Cai Yun   M  32.0   181.0    68.0  China-1  CHN  2012 Summer  2012
# 19563  Chai Biao   M  21.0   186.0    80.0  China-2  CHN  2012 Summer  2012
# 19563  Chai Biao   M  25.0   186.0    80.0  China-2  CHN  2016 Summer  2016
#
#        Season            City      Sport                    Event   Medal  \
# ID
# 17299  Summer          Athina  Badminton  Badminton Men's Doubles     NaN
# 17299  Summer         Beijing  Badminton  Badminton Men's Doubles  Silver
# 17299  Summer          London  Badminton  Badminton Men's Doubles    Gold
# 19563  Summer          London  Badminton  Badminton Men's Doubles     NaN
# 19563  Summer  Rio de Janeiro  Badminton  Badminton Men's Doubles     NaN
#
#       Country
# ID
# 17299   China
# 17299   China
# ...

# %%
#so remove those unnecessary column
data.drop(['Team','NOC'],axis=1,inplace=True)
#now our data
data
# Out:
#                       Name Sex   Age  Height  Weight        Games  Year  \
# ID
# 1                A Dijiang   M  24.0   180.0    80.0  1992 Summer  1992
# 2                 A Lamusi   M  23.0   170.0    60.0  2012 Summer  2012
# 602          Abudoureheman   M  22.0   182.0    75.0  2000 Summer  2000
# 1463             Ai Linuer   M  25.0   160.0    62.0  2004 Summer  2004
# 1464             Ai Yanhan   F  14.0   168.0    54.0  2016 Summer  2016
# ...                    ...  ..   ...     ...     ...          ...   ...
# 120575     Mamorallo Tjoka   F  23.0   150.0    56.0  2008 Summer  2008
# 120575     Mamorallo Tjoka   F  27.0   150.0    56.0  2012 Summer  2012
# 122166  M'apotlaki Ts'elho   F  15.0   175.0    71.0  1996 Summer  1996
# 122215          Lefa Tsapi   M  23.0   170.0    63.0  1984 Summer  1984
# 122299       Mosolesa Tsie   M  20.0   175.0    75.0  2000 Summer  2000
#
#         Season            City       Sport  \
# ID
# 1       Summer       Barcelona  Basketball
# ...

# %%
#checking correlation between columns
plt.figure(figsize=(7,5))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %% [markdown]
# ## EDA:

# %%
#lets see the olympics happened years
yr=data.Year.unique()
yr=np.sort(yr)
yr
# Out:
# array([1896, 1900, 1904, 1906, 1908, 1912, 1920, 1924, 1928, 1932, 1936,
#        1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988,
#        1992, 1994, 1996, 1998, 2000, 2002, 2004, 2006, 2008, 2010, 2012,
#        2014, 2016], dtype=int64)

# %%
#value count of year
data.Year.value_counts()
# Out:
# 1992    16413
# 1988    14676
# 2000    13821
# 1996    13780
# 2016    13688
#         ...
# 1932     2817
# 1900     1898
# 1906     1733
# 1904     1301
# 1896      380
# Name: Year, Length: 35, dtype: int64

# %%
#years with season list
gm=data.Games.unique()
gm=np.sort(gm)
gm
# Out:
# array(['1896 Summer', '1900 Summer', '1904 Summer', '1906 Summer',
#        '1908 Summer', '1912 Summer', '1920 Summer', '1924 Summer',
#        '1924 Winter', '1928 Summer', '1928 Winter', '1932 Summer',
#        '1932 Winter', '1936 Summer', '1936 Winter', '1948 Summer',
#        '1948 Winter', '1952 Summer', '1952 Winter', '1956 Summer',
#        '1956 Winter', '1960 Summer', '1960 Winter', '1964 Summer',
#        '1964 Winter', '1968 Summer', '1968 Winter', '1972 Summer',
#        '1972 Winter', '1976 Summer', '1976 Winter', '1980 Summer',
#        '1980 Winter', '1984 Summer', '1984 Winter', '1988 Summer',
#        '1988 Winter', '1992 Summer', '1992 Winter', '1994 Winter',
#        '1996 Summer', '1998 Winter', '2000 Summer', '2002 Winter',
#        '2004 Summer', '2006 Winter', '2008 Summer', '2010 Winter',
#        '2012 Summer', '2014 Winter', '2016 Summer'], dtype=object)

# %%
#value count of games
data.Games.value_counts()
# Out:
# 2000 Summer    13821
# 1996 Summer    13780
# 2016 Summer    13688
# 2008 Summer    13602
# 2004 Summer    13443
#                ...
# 1936 Winter      895
# 1928 Winter      582
# 1924 Winter      460
# 1896 Summer      380
# 1932 Winter      352
# Name: Games, Length: 51, dtype: int64

# %%
#host locations for olympics
ci=data.City.unique()
ci=np.sort(ci)
ci
# Out:
# array(['Albertville', 'Amsterdam', 'Antwerpen', 'Athina', 'Atlanta',
#        'Barcelona', 'Beijing', 'Berlin', 'Calgary', 'Chamonix',
#        "Cortina d'Ampezzo", 'Garmisch-Partenkirchen', 'Grenoble',
#        'Helsinki', 'Innsbruck', 'Lake Placid', 'Lillehammer', 'London',
#        'Los Angeles', 'Melbourne', 'Mexico City', 'Montreal', 'Moskva',
#        'Munich', 'Nagano', 'Oslo', 'Paris', 'Rio de Janeiro', 'Roma',
#        'Salt Lake City', 'Sankt Moritz', 'Sapporo', 'Sarajevo', 'Seoul',
#        'Sochi', 'Squaw Valley', 'St. Louis', 'Stockholm', 'Sydney',
#        'Tokyo', 'Torino', 'Vancouver'], dtype=object)

# %%
#find the host location for diff seasons
host=data.pivot_table(index=['City','Season','Year'],values='Games')
host
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
#find no of playes played in each season 
#ID(index) is unique for each player
no=[]
no_m=[]
no_f=[]
cc=[]
for i in gm:
    no.append(data[data.Games==i].index.nunique())
    cc.append(data[data.Games==i].Country.nunique())
    no_m.append(data[(data.Sex=='M')&(data.Games==i)].index.nunique())
    no_f.append(data[(data.Sex=='F')&(data.Games==i)].index.nunique())
#putting into dataframe
game_player=pd.DataFrame(list(zip(gm,cc,no,no_m,no_f)),columns=['Games','Country_Count','Total_Players','Male','Female'])
game_player
# Out:
#           Games  Country_Count  Total_Players  Male  Female
# 0   1896 Summer             12            176   176       0
# 1   1900 Summer             31           1224  1201      23
# 2   1904 Summer             14            650   644       6
# 3   1906 Summer             20            841   835       6
# 4   1908 Summer             22           2024  1980      44
# ..          ...            ...            ...   ...     ...
# 46  2008 Summer            203          10899  6290    4609
# 47  2010 Winter             81           2536  1503    1033
# 48  2012 Summer            204          10517  5863    4654
# 49  2014 Winter             88           2745  1643    1102
# 50  2016 Summer            206          11179  6145    5034
#
# [51 rows x 5 columns]

# %%
#splitting data with season
gps=game_player[game_player.Games.str.endswith('Summer')]
gpw=game_player[game_player.Games.str.endswith('Winter')]

# %%
#plot for country count
sns.set_style("whitegrid")
plt.figure(figsize=(18,8))
plt.suptitle('No of Countries Participated in each Season')
plt.subplot(1,2,1)
sns.barplot(data=gps,x='Games',y='Country_Count',palette='tab10')
plt.xticks(rotation='vertical')
plt.subplot(1,2,2)
sns.barplot(data=gpw,x='Games',y='Country_Count',palette='Paired')
plt.xticks(rotation='vertical')
plt.show()

# %%
#plot for players count
plt.figure(figsize=(18,8))
plt.suptitle('No of Players Participated in each Season')
plt.subplot(1,2,1)
sns.barplot(data=gps,x='Games',y='Total_Players',palette='flare')
plt.xticks(rotation='vertical')
plt.subplot(1,2,2)
sns.barplot(data=gpw,x='Games',y='Total_Players',palette='crest')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# From both the observation we can get to know that max no of country and players are participated in summer olympics

# %%
#maximum players played in
game_player.nlargest(1,'Total_Players')
# Out:
#           Games  Country_Count  Total_Players  Male  Female
# 50  2016 Summer            206          11179  6145    5034

# %%
#top 10
t10gp=game_player.nlargest(10,'Total_Players')
t10gp
# Out:
#           Games  Country_Count  Total_Players  Male  Female
# 50  2016 Summer            206          11179  6145    5034
# 46  2008 Summer            203          10899  6290    4609
# 42  2000 Summer            199          10647  6579    4068
# 44  2004 Summer            200          10557  6257    4300
# 48  2012 Summer            204          10517  5863    4654
# 40  1996 Summer            196          10339  6822    3517
# 37  1992 Summer            168           9386  6663    2723
# 35  1988 Summer            156           8454  6251    2203
# 27  1972 Summer            120           7114  6054    1060
# 33  1984 Summer            139           6798  5229    1569

# %%
#top 10 seasons with players count
xa=list(t10gp.Games)
x_axis=np.arange(10)
plt.figure(figsize=(8,5))
plt.bar(x_axis-0.2,'Male',0.4,data=t10gp,label='Male')
plt.bar(x_axis+0.2,'Female',0.4,data=t10gp,label='Female')
plt.title('Top 10 season with players count')
plt.xticks(x_axis,xa,rotation='vertical')
plt.legend(['Male','Female'])
plt.show()

# %%
#extract sport column values
sp=data.Sport.unique()
sp=np.sort(sp)
sp
# Out:
# array(['Aeronautics', 'Alpine Skiing', 'Alpinism', 'Archery',
#        'Art Competitions', 'Athletics', 'Badminton', 'Baseball',
#        'Basketball', 'Basque Pelota', 'Beach Volleyball', 'Biathlon',
#        'Bobsleigh', 'Boxing', 'Canoeing', 'Cricket', 'Croquet',
#        'Cross Country Skiing', 'Curling', 'Cycling', 'Diving',
#        'Equestrianism', 'Fencing', 'Figure Skating', 'Football',
#        'Freestyle Skiing', 'Golf', 'Gymnastics', 'Handball', 'Hockey',
#        'Ice Hockey', 'Jeu De Paume', 'Judo', 'Lacrosse', 'Luge',
#        'Military Ski Patrol', 'Modern Pentathlon', 'Motorboating',
#        'Nordic Combined', 'Polo', 'Racquets', 'Rhythmic Gymnastics',
#        'Roque', 'Rowing', 'Rugby', 'Rugby Sevens', 'Sailing', 'Shooting',
#        'Short Track Speed Skating', 'Skeleton', 'Ski Jumping',
#        'Snowboarding', 'Softball', 'Speed Skating', 'Swimming',
#        'Synchronized Swimming', 'Table Tennis', 'Taekwondo', 'Tennis',
# ...

# %%
#value count of sports
data.Sport.value_counts()
# Out:
# Athletics        38624
# Gymnastics       26707
# Swimming         23195
# Shooting         11448
# Cycling          10827
#                  ...
# Racquets            12
# Jeu De Paume        11
# Roque                4
# Basque Pelota        2
# Aeronautics          1
# Name: Sport, Length: 66, dtype: int64

# %%
#find no of playes played in each sport
#ID(index) is unique for each player
no=[]
no_m=[]
no_f=[]
for i in sp:
    no.append(data[data.Sport==i].index.nunique())
    no_m.append(data[(data.Sex=='M')&(data.Sport==i)].index.nunique())
    no_f.append(data[(data.Sex=='F')&(data.Sport==i)].index.nunique())
#putting into dataframe
sport_player=pd.DataFrame(list(zip(sp,no,no_m,no_f)),columns=['Sport','Total_Players','Male','Female'])
sport_player
# Out:
#                Sport  Total_Players  Male  Female
# 0        Aeronautics              1     1       0
# 1      Alpine Skiing           2735  1739     996
# 2           Alpinism             25    24       1
# 3            Archery           1113   613     500
# 4   Art Competitions           1814  1610     204
# ..               ...            ...   ...     ...
# 61        Tug-Of-War            160   160       0
# 62        Volleyball           2503  1374    1129
# 63        Water Polo           2599  2262     337
# 64     Weightlifting           2882  2526     356
# 65         Wrestling           4988  4766     222
#
# [66 rows x 4 columns]

# %%
#extract event column values
ev=data.Event.unique()
ev=np.sort(ev)
pd.DataFrame(ev)
# Out:
#                                                   0
# 0                     Aeronautics Mixed Aeronautics
# 1                      Alpine Skiing Men's Combined
# 2                      Alpine Skiing Men's Downhill
# 3                  Alpine Skiing Men's Giant Slalom
# 4                        Alpine Skiing Men's Slalom
# ..                                              ...
# 760          Wrestling Women's Flyweight, Freestyle
# 761        Wrestling Women's Heavyweight, Freestyle
# 762  Wrestling Women's Light-Heavyweight, Freestyle
# 763        Wrestling Women's Lightweight, Freestyle
# 764       Wrestling Women's Middleweight, Freestyle
#
# [765 rows x 1 columns]

# %%
#find no of playes played in each event
#ID(index) is unique for each player
no=[]
no_m=[]
no_f=[]
for i in ev:
    no.append(data[data.Event==i].index.nunique())
    no_m.append(data[(data.Sex=='M')&(data.Event==i)].index.nunique())
    no_f.append(data[(data.Sex=='F')&(data.Event==i)].index.nunique())
#putting into dataframe
event_player=pd.DataFrame(list(zip(ev,no,no_m,no_f)),columns=['Event','Total_Players','Male','Female'])
event_player
# Out:
#                                               Event  Total_Players  Male  \
# 0                     Aeronautics Mixed Aeronautics              1     1
# 1                      Alpine Skiing Men's Combined            441   441
# 2                      Alpine Skiing Men's Downhill            832   832
# 3                  Alpine Skiing Men's Giant Slalom           1110  1110
# 4                        Alpine Skiing Men's Slalom           1136  1136
# ..                                              ...            ...   ...
# 760          Wrestling Women's Flyweight, Freestyle             52     0
# 761        Wrestling Women's Heavyweight, Freestyle             46     0
# 762  Wrestling Women's Light-Heavyweight, Freestyle             18     0
# 763        Wrestling Women's Lightweight, Freestyle             51     0
# 764       Wrestling Women's Middleweight, Freestyle             49     0
#
#      Female
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...

# %%
#event that has maximum players played - overall & men
event_player.nlargest(1,'Total_Players')
# Out:
#                        Event  Total_Players  Male  Female
# 348  Football Men's Football           5427  5427       0

# %%
#event that has maximum players played - women
event_player.nlargest(1,'Female')
# Out:
#                                         Event  Total_Players  Male  Female
# 386  Gymnastics Women's Individual All-Around           1281     0    1281

# %%
#event that has maximum players played - men & women
event_player[(event_player.Male!=0)&(event_player.Female!=0)].nlargest(1,'Total_Players')
# Out:
#                                    Event  Total_Players  Male  Female
# 491  Sailing Mixed Three Person Keelboat            744   741       3

# %%
#extract country column values
ct=data.Country.unique()
ct=np.sort(ct)
pd.DataFrame(ct)
# Out:
#                            0
# 0                Afghanistan
# 1                    Albania
# 2                    Algeria
# 3             American Samoa
# 4                    Andorra
# ..                       ...
# 204  Virgin Islands, British
# 205       Virgin Islands, US
# 206                    Yemen
# 207                   Zambia
# 208                 Zimbabwe
#
# [209 rows x 1 columns]

# %%
#value count of country
data.Country.value_counts()
# Out:
# USA            18604
# Germany        15787
# France         12551
# UK             12115
# Russia         11692
#                ...
# Timor-Leste        9
# Kosovo             8
# Tuvalu             7
# South Sudan        3
# Unknown            2
# Name: Country, Length: 209, dtype: int64

# %%
#find no of playes played for each country
#ID(index) is unique for each player
no=[]
no_m=[]
no_f=[]
for i in ct:
    no.append(data[data.Country==i].index.nunique())
    no_m.append(data[(data.Sex=='M')&(data.Country==i)].index.nunique())
    no_f.append(data[(data.Sex=='F')&(data.Country==i)].index.nunique())
#putting into dataframe
country_player=pd.DataFrame(list(zip(ct,no,no_m,no_f)),columns=['Country','Total_Players','Male','Female'])
country_player
# Out:
#                      Country  Total_Players  Male  Female
# 0                Afghanistan            103    99       4
# 1                    Albania             45    29      16
# 2                    Algeria            373   318      55
# 3             American Samoa             29    24       5
# 4                    Andorra             61    43      18
# ..                       ...            ...   ...     ...
# 204  Virgin Islands, British             28    25       3
# 205       Virgin Islands, US            150   127      23
# 206                    Yemen             43    39       4
# 207                   Zambia            145   132      13
# 208                 Zimbabwe            205   132      73
#
# [209 rows x 4 columns]

# %%
#which country has maximum players played
country_player.nlargest(1,'Total_Players')
# Out:
#     Country  Total_Players  Male  Female
# 194     USA           9653  7040    2613

# %%
#take no of players participated and no of players got medal for each country
no=[]
nos=[]
for i in ct:
    no.append(data[data.Country==i].index.nunique())
    nos.append(data[(data.Country==i) & (~data.Medal.isnull())].index.nunique())
#putting into dataframe
part_med=pd.DataFrame(list(zip(ct,no,nos)),columns=['Country','Participated_Players','Medal_Won_Players'])
part_med
# Out:
#                      Country  Participated_Players  Medal_Won_Players
# 0                Afghanistan                   103                  1
# 1                    Albania                    45                  0
# 2                    Algeria                   373                 14
# 3             American Samoa                    29                  0
# 4                    Andorra                    61                  0
# ..                       ...                   ...                ...
# 204  Virgin Islands, British                    28                  0
# 205       Virgin Islands, US                   150                  1
# 206                    Yemen                    43                  0
# 207                   Zambia                   145                  2
# 208                 Zimbabwe                   205                 16
#
# [209 rows x 3 columns]

# %%
t10pm=part_med.sort_values(by='Medal_Won_Players',ascending=False).nlargest(10,'Medal_Won_Players')
t10pm
# Out:
#          Country  Participated_Players  Medal_Won_Players
# 194          USA                  9653               3836
# 152       Russia                  5610               2612
# 67       Germany                  7575               2565
# 193           UK                  6281               1601
# 63        France                  6170               1277
# 87         Italy                  4935               1117
# 178       Sweden                  3787               1108
# 33        Canada                  4812               1064
# 10     Australia                  3870                886
# 129  Netherlands                  2939                731

# %%
#checking correlation b/w participated and medal won players
part_med.corr()
# Out:
#                       Participated_Players  Medal_Won_Players
# Participated_Players              1.000000           0.941437
# Medal_Won_Players                 0.941437           1.000000

# %%
#bar plot b/w participated and medal won players
plt.figure(figsize=(10,6))
plt.title('No of Paticipated Players vs No of Medal Won Players')
plt.bar(x='Country',height='Participated_Players',data=t10pm,label='Participated_Players')
plt.bar(x='Country',height='Medal_Won_Players',data=t10pm,label='Medal_Won_Players')
plt.legend(['Participated_Players','Medal_Won_Players'])
plt.show()

# %%
#which country has maximum medal won players
part_med.nlargest(1,'Medal_Won_Players')
# Out:
#     Country  Participated_Players  Medal_Won_Players
# 194     USA                  9653               3836

# %%
#histogram of age
plt.figure(figsize=(15,10))
plt.title("Age Distribution of Players")
plt.hist(data.Age,bins=np.arange(10,60))
plt.xlabel("Age of players")
plt.ylabel("Number of players")
plt.show()

# %% [markdown]
# from this histogram, we can say that maximum of people has a age of 20 to 30.

# %%
#histogram of age for gold won players
datag=data[data.Medal=='Gold']
plt.figure(figsize=(15,10))
plt.title("Age Distribution of Gold Won Players")
plt.hist(datag.Age,bins=np.arange(10,60))
plt.xlabel("Age of players")
plt.ylabel("Number of players")
plt.show()

# %%
#histogram of age for bronze won players
datab=data[data.Medal=='Bronze']
plt.figure(figsize=(15,10))
plt.title("Age Distribution of Bronze Won Players")
plt.hist(datab.Age,bins=np.arange(10,60))
plt.xlabel("Age of players")
plt.ylabel("Number of players")
plt.show()

# %%
#histogram of age for silver won players
datas=data[data.Medal=='Silver']
plt.figure(figsize=(15,10))
plt.title("Age Distribution of Silver Won Players")
plt.hist(datas.Age,bins=np.arange(10,60))
plt.xlabel("Age of players")
plt.ylabel("Number of players")
plt.show()

# %% [markdown]
# as per above three histogram we can see that medal won players also maximum in the age group of 20 to 30

# %%
#dropping duplicates based on some columns for team medal 
#Suppose there is a team game(Hockey) which consists of 11 players and the medal will be received by all the 11 players who are belonging to the same country. Hence we are calculating all the total 11 medals instead of 1 medal for that particular country due to which there are some misleading errors. Hence we can remove those duplicate values
data_m=data.drop_duplicates(subset=['Games','Year','Season','City','Sport','Event','Medal','Country'])

# %%
#now our data
data_m
# Out:
#                    Name Sex   Age  Height  Weight        Games  Year  Season  \
# ID
# 1             A Dijiang   M  24.0   180.0    80.0  1992 Summer  1992  Summer
# 2              A Lamusi   M  23.0   170.0    60.0  2012 Summer  2012  Summer
# 602       Abudoureheman   M  22.0   182.0    75.0  2000 Summer  2000  Summer
# 1463          Ai Linuer   M  25.0   160.0    62.0  2004 Summer  2004  Summer
# 1464          Ai Yanhan   F  14.0   168.0    54.0  2016 Summer  2016  Summer
# ...                 ...  ..   ...     ...     ...          ...   ...     ...
# 119563    Masempe Theko   F  25.0   175.0    71.0  2012 Summer  2012  Summer
# 120575  Mamorallo Tjoka   F  23.0   150.0    56.0  2008 Summer  2008  Summer
# 120575  Mamorallo Tjoka   F  27.0   150.0    56.0  2012 Summer  2012  Summer
# 122215       Lefa Tsapi   M  23.0   170.0    63.0  1984 Summer  1984  Summer
# 122299    Mosolesa Tsie   M  20.0   175.0    75.0  2000 Summer  2000  Summer
#
# ...

# %%
#copying medal data for counting purpose for pivot table
data_m['Medal1']=data_m.Medal
data['Medal1']=data.Medal

# %%
#creating pivot table for country medal count
md=data_m.pivot_table(values='Medal',index=['Country'],aggfunc='count')
#sorting values in descending order
md.sort_values(by='Medal',ascending=False,inplace=True)
#now look our pivot
md=md[md.Medal!=0]
md
# Out:
#             Medal
# Country
# USA          2823
# Russia       1916
# Germany      1766
# UK            919
# France        879
# ...           ...
# Senegal         1
# Fiji            1
# Macedonia       1
# Montenegro      1
# Botswana        1
#
# [137 rows x 1 columns]

# %%
#top 10 countries
top10=md.head(10)
top10
# Out:
#            Medal
# Country
# USA         2823
# Russia      1916
# Germany     1766
# UK           919
# France       879
# Italy        722
# Sweden       657
# China        598
# Australia    531
# Hungary      510

# %%
#pie chart for top 10 country and their medal count
plt.pie(top10.Medal,labels=top10.index,radius=3,autopct='%1.1f%%')
plt.title('Top 10 Country and their Medal Counts',pad=200,fontdict={'fontsize':20},loc='center')
plt.show()

# %%
#bar chart for the same
plt.figure(figsize=(10,7))
plt.title('Top 10 Country and their Medal Counts')
ax=sns.barplot(data=top10,x=top10.index,y='Medal')
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+1,rect.get_height(),horizontalalignment='center',fontsize=11)
plt.show()

# %%
#creating pivot for medal count
gp=data.pivot_table(index=['Sex','Medal'],values='Medal1',aggfunc='count')
#output for pivot
gp
#resetting index
gp=gp.reset_index()
#pivot after resetting index
gp
# Out:
#   Sex   Medal  Medal1
# 0   F  Bronze    3771
# 1   F    Gold    3747
# 2   F  Silver    3735
# 3   M  Bronze    9524
# 4   M    Gold    9622
# 5   M  Silver    9373

# %%
#create countplot
countplot, ax=plt.subplots(figsize=(9,5))
ax=sns.countplot(x='Sex',hue='Medal',data=data)
ax.set_title('No of Medals won by Gender')
ax.set_ylabel('Count of Medal')
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+1,rect.get_height(),horizontalalignment='center',fontsize=11)
plt.show()

# %%
#creating pie chart
plt.pie(gp.Medal1,labels=['Female-Gold','Female-Bronze','Female-Silver','Male-Gold','Male-Bronze','Male-Silver'],radius=1.5,autopct='%1.1f%%')
plt.title('Medal counts based on Gender',pad=70,fontdict={'fontsize':15},loc='center')
plt.show()

# %%
#creating pivot table for country medal count
mtc=data_m.pivot_table(values=['Medal1'],index=['Country','Medal'],aggfunc='count')
#renaming column
mtc=mtc.rename(columns={'Medal1':'Medal_count'})
#country and medal counts
mtc=mtc[mtc.Medal_count!=0]
mtc
# Out:
#                     Medal_count
# Country     Medal
# Afghanistan Bronze            2
# Algeria     Bronze            8
#             Gold              5
#             Silver            4
# Argentina   Bronze           28
# ...                         ...
# Zambia      Bronze            1
#             Silver            1
# Zimbabwe    Bronze            1
#             Gold              3
#             Silver            4
#
# [330 rows x 1 columns]

# %%
#top 10 medal counts
mtct10=mtc.nlargest(10,'Medal_count')
mtct10.reset_index(inplace=True)
mtct10
# Out:
#    Country   Medal  Medal_count
# 0      USA    Gold         1131
# 1      USA  Silver          901
# 2      USA  Bronze          791
# 3   Russia    Gold          727
# 4   Russia  Silver          600
# 5  Germany  Bronze          596
# 6  Germany  Silver          592
# 7   Russia  Bronze          589
# 8  Germany    Gold          578
# 9   France  Bronze          329

# %% [markdown]
# in this pivot we can see three countries are repeating

# %%
#top 3
mtct10.drop(index=9,inplace=True)
mtct10
# Out:
#    Country   Medal  Medal_count
# 0      USA    Gold         1131
# 1      USA  Silver          901
# 2      USA  Bronze          791
# 3   Russia    Gold          727
# 4   Russia  Silver          600
# 5  Germany  Bronze          596
# 6  Germany  Silver          592
# 7   Russia  Bronze          589
# 8  Germany    Gold          578

# %%
#barplot for the pivot
plt.figure(figsize=(8,5))
ax=sns.barplot(data=mtct10,x='Country',y='Medal_count',hue='Medal')
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+1,rect.get_height(),horizontalalignment='center',fontsize=11)
plt.legend(loc='upper right')
plt.show()

# %%
#USA's medal counts
usamedal=mtc.loc['USA']
usamedal
# Out:
#         Medal_count
# Medal
# Bronze          791
# Gold           1131
# Silver          901

# %%
#plot for usa
ax=sns.barplot(data=usamedal,x=usamedal.index,y='Medal_count')
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+1,rect.get_height(),horizontalalignment='center',fontsize=11)
plt.title('USA Medal Count')
plt.show()

# %%
#lets extract top 10 country
t10c=list(top10.index)
mtc.reset_index(inplace=True)
top10m=mtc[mtc.Country.isin(t10c)]
top10m.sort_values('Medal_count',ascending=False,inplace=True)
top10m
# Out:
#        Country   Medal  Medal_count
# 303        USA    Gold         1131
# 304        USA  Silver          901
# 302        USA  Bronze          791
# 239     Russia    Gold          727
# 240     Russia  Silver          600
# ..         ...     ...          ...
# 116    Hungary  Bronze          176
# 12   Australia  Silver          174
# 51       China  Bronze          173
# 11   Australia    Gold          156
# 118    Hungary  Silver          156
#
# [30 rows x 3 columns]

# %%
#plot for top 10 countries with each category medal
barplot, ax=plt.subplots(figsize=(18,7))
ax=sns.barplot(data=top10m,x='Country',y='Medal_count',hue='Medal')
plt.title("Top 10 Countries and their Medal Count")
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+20,round(rect.get_height()),horizontalalignment='center',fontsize=11)
plt.show()

# %%
#creating pivot table for country medal count with season
mc=data_m.pivot_table(values=['Medal1'],index=['Country','Games'],aggfunc='count')
#renaming column
mc=mc.rename(columns={'Medal1':'Medal_count'})
#country and medal counts with season
mc=mc[mc.Medal_count!=0]
mc
# Out:
#                          Medal_count
# Country     Games
# Afghanistan 2008 Summer            1
#             2012 Summer            1
# Algeria     1984 Summer            2
#             1992 Summer            2
#             1996 Summer            3
# ...                              ...
# Zambia      1984 Summer            1
#             1996 Summer            1
# Zimbabwe    1980 Summer            1
#             2004 Summer            3
#             2008 Summer            4
#
# [1644 rows x 1 columns]

# %%
#season wise top 10 medal won countries
mct10=mc.nlargest(10,'Medal_count')
mct10.reset_index(inplace=True)
mct10
# Out:
#    Country        Games  Medal_count
# 0      USA  1904 Summer          230
# 1   Russia  1980 Summer          195
# 2      USA  1984 Summer          173
# 3       UK  1908 Summer          143
# 4  Germany  1988 Summer          142
# 5   Russia  1988 Summer          131
# 6  Germany  1976 Summer          129
# 7  Germany  1980 Summer          126
# 8   Russia  1976 Summer          125
# 9      USA  2016 Summer          121

# %%
#now take sports column to analyze
#creating pivot table
ms=data_m.pivot_table(values=['Medal1'],index=['Country','Sport'],aggfunc='count')
#renaming column
ms=ms.rename(columns={'Medal1':'Medal_count'})
#country and medal count with respective sport
ms=ms[ms.Medal_count!=0]
#our pivot
ms
# Out:
#                               Medal_count
# Country            Sport
# Afghanistan        Taekwondo            2
# Algeria            Athletics            9
#                    Boxing               6
#                    Judo                 2
# Argentina          Athletics            5
# ...                                   ...
# Virgin Islands, US Sailing              1
# Zambia             Athletics            1
#                    Boxing               1
# Zimbabwe           Hockey               1
#                    Swimming             7
#
# [1307 rows x 1 columns]

# %%
#spotrs wise top 10 medal won countries
ms.nlargest(10,'Medal_count')
# Out:
#                       Medal_count
# Country   Sport
# USA       Athletics           816
#           Swimming            550
# Russia    Athletics           291
# Germany   Athletics           264
# Russia    Gymnastics          241
# UK        Athletics           212
# Australia Swimming            201
# Russia    Wrestling           192
# Germany   Swimming            188
# USA       Diving              135

# %%
#creating pivot table sports with individual event
spetm=data_m.pivot_table(index=['Country','Sport','Event'],values='Medal',aggfunc='count')
#renaming column
spetm=spetm.rename(columns={'Medal':'Medal_count'})
#country and medal count with respective sport
spetm=spetm[spetm.Medal_count!=0]
#our pivot
spetm
# Out:
#                                                                      Medal_count
# Country     Sport     Event
# Afghanistan Taekwondo Taekwondo Men's Featherweight                            1
#                       Taekwondo Men's Flyweight                                1
# Algeria     Athletics Athletics Men's 1,500 metres                             3
#                       Athletics Men's 5,000 metres                             1
#                       Athletics Men's 800 metres                               2
# ...                                                                          ...
# Zimbabwe    Hockey    Hockey Women's Hockey                                    1
#             Swimming  Swimming Women's 100 metres Backstroke                   2
#                       Swimming Women's 200 metres Backstroke                   2
#                       Swimming Women's 200 metres Individual Medley            2
# ...

# %%
#spotrs with event wise top 10 medal won countries
spetm.nlargest(10,'Medal_count')
# Out:
#                                                         Medal_count
# Country Sport     Event
# USA     Athletics Athletics Men's 110 metres Hurdles             57
#                   Athletics Men's Shot Put                       51
#                   Athletics Men's Long Jump                      49
#                   Athletics Men's 200 metres                     46
#                   Athletics Men's 400 metres                     45
#                   Athletics Men's Pole Vault                     44
#                   Athletics Men's 100 metres                     41
#                   Athletics Men's 400 metres Hurdles             41
#         Diving    Diving Men's Springboard                       39
#         Swimming  Swimming Men's 100 metres Backstroke           37

# %%
#now take type of medal into consideration
#creating pivot table
cm=data_m.pivot_table(values=['Medal1'],index=['Country','Games','Medal'],aggfunc='count')
#renaming column
cm=cm.rename(columns={'Medal1':'Medal_count'})
#removing zero medals
cm=cm[cm.Medal_count!=0]
#our pivot
cm
# Out:
#                                 Medal_count
# Country     Games       Medal
# Afghanistan 2008 Summer Bronze            1
#             2012 Summer Bronze            1
# Algeria     1984 Summer Bronze            2
#             1992 Summer Bronze            1
#                         Gold              1
# ...                                     ...
# Zimbabwe    2004 Summer Bronze            1
#                         Gold              1
#                         Silver            1
#             2008 Summer Gold              1
#                         Silver            3
#
# [3644 rows x 1 columns]

# %%
#spotrs wise top 10 medal won countries
cm.nlargest(10,'Medal_count')
# Out:
#                             Medal_count
# Country Games       Medal
# USA     1984 Summer Gold             82
# Russia  1980 Summer Gold             80
# USA     1904 Summer Silver           79
#                     Gold             76
#                     Bronze           75
# Russia  1980 Summer Silver           69
# USA     1984 Summer Silver           61
# UK      1908 Summer Gold             56
# Russia  1988 Summer Gold             54
# China   2008 Summer Gold             51

# %%
#find medal count of each player
pl=data.pivot_table(index=['ID','Name','Medal'],values='Medal1',aggfunc='count')
pl=pl.rename(columns={'Medal1':'Medal_count'})
pl
# Out:
#                                                    Medal_count
# ID     Name                                Medal
# 4      Edgar Lindenau Aabye                Gold              1
# 15     Arvo Ossian Aaltonen                Bronze            2
# 16     Juhamatti Tapio Aaltonen            Bronze            1
# 17     Paavo Johannes Aaltonen             Bronze            2
#                                            Gold              3
# ...                                                        ...
# 135553 Galina Ivanovna Zybina (-Fyodorova) Gold              1
#                                            Silver            1
# 135554 Bogusaw Zych                        Bronze            1
# 135563 Olesya Nikolayevna Zykina           Bronze            1
#                                            Silver            1
#
# [33745 rows x 1 columns]

# %%
#top 10 players based on medal count
pl.sort_values('Medal_count',ascending=False,inplace=True)
pl.nlargest(10,'Medal_count')
# Out:
#                                                               Medal_count
# ID     Name                                            Medal
# 94406  Michael Fred Phelps, II                         Gold            23
# 33557  Raymond Clarence "Ray" Ewry                     Gold            10
# 67046  Larysa Semenivna Latynina (Diriy-)              Gold             9
# 69210  Frederick Carlton "Carl" Lewis                  Gold             9
# 87390  Paavo Johannes Nurmi                            Gold             9
# 113912 Mark Andrew Spitz                               Gold             9
# 11642  Matthew Nicholas "Matt" Biondi                  Gold             8
# 57998  Sawao Kato                                      Gold             8
# 11951  Ole Einar Bjrndalen                             Gold             8
# 119922 Jennifer Elisabeth "Jenny" Thompson (-Cumpelik) Gold             8

# %%
#highest medal won player till date
data.loc[94406]
# Out:
#                           Name Sex   Age  Height  Weight        Games  Year  \
# ID
# 94406  Michael Fred Phelps, II   M  15.0   193.0    91.0  2000 Summer  2000
# 94406  Michael Fred Phelps, II   M  19.0   193.0    91.0  2004 Summer  2004
# 94406  Michael Fred Phelps, II   M  19.0   193.0    91.0  2004 Summer  2004
# 94406  Michael Fred Phelps, II   M  19.0   193.0    91.0  2004 Summer  2004
# 94406  Michael Fred Phelps, II   M  19.0   193.0    91.0  2004 Summer  2004
# ...                        ...  ..   ...     ...     ...          ...   ...
# 94406  Michael Fred Phelps, II   M  31.0   193.0    91.0  2016 Summer  2016
# 94406  Michael Fred Phelps, II   M  31.0   193.0    91.0  2016 Summer  2016
# 94406  Michael Fred Phelps, II   M  31.0   193.0    91.0  2016 Summer  2016
# 94406  Michael Fred Phelps, II   M  31.0   193.0    91.0  2016 Summer  2016
# 94406  Michael Fred Phelps, II   M  31.0   193.0    91.0  2016 Summer  2016
#
#        Season            City     Sport  \
# ID
# ...

# %%
#drop that Medal1 column
data_m.drop('Medal1',axis=1,inplace=True)
data.drop('Medal1',axis=1,inplace=True)

# %% [markdown]
# Lets take age column into analysis

# %%
#first take ppl who has age less than 18
below18=data_m[data_m.Age<18]
#data
below18
# Out:
#                                      Name Sex   Age  Height  Weight  \
# ID
# 1464                            Ai Yanhan   F  14.0   168.0    54.0
# 1464                            Ai Yanhan   F  14.0   168.0    54.0
# 6854                              Bai Mei   F  17.0   166.0    46.0
# 7599                         Bao Zhenghua   F  14.0   158.0    71.0
# 11223                          Bi Wenjing   F  14.0   142.0    35.0
# ...                                   ...  ..   ...     ...     ...
# 61644                 Nteboheleng Koaeana   F  17.0   175.0    71.0
# 76418                    Teboho Mathibeli   M  17.0   150.0    51.0
# 95244   Mantokoane Angelina Pitso Sephooa   F  17.0   148.0    45.0
# 95244   Mantokoane Angelina Pitso Sephooa   F  17.0   148.0    45.0
# 109961               Lineo Florence Shoai   F  17.0   175.0    71.0
#
#               Games  Year  Season            City                Sport  \
# ID
# ...

# %%
#take no of players participated and no of players got medal for each country
no=[]
nos=[]
for i in ct:
    no.append(below18[below18.Country==i].index.nunique())
    nos.append(below18[(below18.Country==i) & (~below18.Medal.isnull())].index.nunique())
#putting into dataframe
blw18_part_med=pd.DataFrame(list(zip(ct,no,nos)),columns=['Country','Participated_Players','Medal_Won_Players'])
blw18_part_med
# Out:
#                      Country  Participated_Players  Medal_Won_Players
# 0                Afghanistan                     1                  0
# 1                    Albania                     5                  0
# 2                    Algeria                    10                  0
# 3             American Samoa                     1                  0
# 4                    Andorra                     6                  0
# ..                       ...                   ...                ...
# 204  Virgin Islands, British                     2                  0
# 205       Virgin Islands, US                     9                  0
# 206                    Yemen                     7                  0
# 207                   Zambia                    12                  0
# 208                 Zimbabwe                    17                  0
#
# [209 rows x 3 columns]

# %%
#top 10 countries
bt10=blw18_part_med.nlargest(10,'Medal_Won_Players')
bt10
# Out:
#          Country  Participated_Players  Medal_Won_Players
# 194          USA                   258                131
# 67       Germany                   134                 54
# 152       Russia                   118                 42
# 39         China                   135                 35
# 10     Australia                   132                 27
# 151      Romania                    71                 24
# 193           UK                   128                 18
# 33        Canada                   124                 13
# 171  South Korea                   122                 13
# 90         Japan                   105                 12

# %%
#plot for players count
plt.figure(figsize=(18,8))
plt.suptitle('No of Players Participated and Medal won in Top 10 Country')
plt.subplot(1,2,1)
sns.barplot(data=bt10,x='Country',y='Participated_Players',palette='flare')
plt.xticks(rotation='vertical')
plt.subplot(1,2,2)
sns.barplot(data=bt10,x='Country',y='Medal_Won_Players',palette='crest')
plt.xticks(rotation='vertical')
plt.show()

# %%
#bar plot b/w participated and medal won players
plt.figure(figsize=(10,6))
plt.title('No of Paticipated Players vs No of Medal Won Players')
plt.bar(x='Country',height='Participated_Players',data=bt10,label='Participated_Players')
plt.bar(x='Country',height='Medal_Won_Players',data=bt10,label='Medal_Won_Players')
plt.legend(['Participated_Players','Medal_Won_Players'])
plt.show()

# %%
#creating pivot for medal count
bp=below18.pivot_table(index=['Country'],values='Medal',aggfunc='count')
#country with medals
bp=bp[bp.Medal!=0]
#pivot table
bp
# Out:
#            Medal
# Country
# Australia     37
# Austria       11
# Belarus        1
# Belgium        1
# Bulgaria       2
# ...          ...
# Thailand       1
# Turkey         1
# UK            20
# USA          170
# Ukraine        5
#
# [43 rows x 1 columns]

# %%
#max medal won 10 country
bp10m=bp.nlargest(10,'Medal')
bp10m
# Out:
#              Medal
# Country
# USA            170
# Germany         80
# Russia          54
# Romania         48
# China           44
# Australia       37
# UK              20
# South Korea     19
# Canada          16
# Hungary         16

# %%
#bar plot for pivot
plt.figure(figsize=(8,5))
ax=sns.barplot(y='Medal',data=bp10m,x=bp10m.index)
plt.title("Top 10 Countries and their Medal Count for below 18 year players")
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+1,round(rect.get_height()),horizontalalignment='center',fontsize=11)
plt.show()

# %%
#creating pivot for medal count with season
bpv=below18.pivot_table(index=['Country','Games'],values='Medal',aggfunc='count')
#non-zero medal rows only
#country with game season and medal count
bpv=bpv[bpv.Medal!=0]
#pivot
bpv
# Out:
#                        Medal
# Country   Games
# Australia 1908 Summer      2
#           1924 Summer      2
#           1932 Summer      1
#           1956 Summer      3
#           1960 Summer      4
# ...                      ...
# USA       2012 Summer      7
#           2016 Summer      1
# Ukraine   1994 Winter      1
#           1996 Summer      3
#           2008 Summer      1
#
# [230 rows x 1 columns]

# %%
#max medal won 10 country
bpv.nlargest(10,'Medal')
# Out:
#                      Medal
# Country Games
# Germany 1980 Summer     24
# USA     1968 Summer     22
#         1964 Summer     17
# Germany 1976 Summer     16
# USA     1924 Summer     11
#         1972 Summer     11
# Germany 1972 Summer     10
# USA     1984 Summer     10
# Romania 1984 Summer      9
# China   2000 Summer      8

# %%
#now take ppl who has age greater than 18
above18=data_m[data_m.Age>=18]
#data
above18
# Out:
#                    Name Sex   Age  Height  Weight        Games  Year  Season  \
# ID
# 1             A Dijiang   M  24.0   180.0    80.0  1992 Summer  1992  Summer
# 2              A Lamusi   M  23.0   170.0    60.0  2012 Summer  2012  Summer
# 602       Abudoureheman   M  22.0   182.0    75.0  2000 Summer  2000  Summer
# 1463          Ai Linuer   M  25.0   160.0    62.0  2004 Summer  2004  Summer
# 3605        An Weijiang   M  22.0   178.0    72.0  2006 Winter  2006  Winter
# ...                 ...  ..   ...     ...     ...          ...   ...     ...
# 119563    Masempe Theko   F  25.0   175.0    71.0  2012 Summer  2012  Summer
# 120575  Mamorallo Tjoka   F  23.0   150.0    56.0  2008 Summer  2008  Summer
# 120575  Mamorallo Tjoka   F  27.0   150.0    56.0  2012 Summer  2012  Summer
# 122215       Lefa Tsapi   M  23.0   170.0    63.0  1984 Summer  1984  Summer
# 122299    Mosolesa Tsie   M  20.0   175.0    75.0  2000 Summer  2000  Summer
#
# ...

# %%
#take no of players participated and no of players got medal for each country
no=[]
nos=[]
for i in ct:
    no.append(above18[above18.Country==i].index.nunique())
    nos.append(above18[(above18.Country==i) & (~above18.Medal.isnull())].index.nunique())
#putting into dataframe
abv18_part_med=pd.DataFrame(list(zip(ct,no,nos)),columns=['Country','Participated_Players','Medal_Won_Players'])
abv18_part_med
# Out:
#                      Country  Participated_Players  Medal_Won_Players
# 0                Afghanistan                    62                  1
# 1                    Albania                    39                  0
# 2                    Algeria                   241                 14
# 3             American Samoa                    26                  0
# 4                    Andorra                    43                  0
# ..                       ...                   ...                ...
# 204  Virgin Islands, British                    20                  0
# 205       Virgin Islands, US                   101                  1
# 206                    Yemen                    36                  0
# 207                   Zambia                    98                  2
# 208                 Zimbabwe                   124                  2
#
# [209 rows x 3 columns]

# %%
#top 10 countries
at10=abv18_part_med.nlargest(10,'Medal_Won_Players')
at10
# Out:
#        Country  Participated_Players  Medal_Won_Players
# 194        USA                  4266               1892
# 152     Russia                  2805               1289
# 67     Germany                  3222               1180
# 193         UK                  2733                700
# 63      France                  2607                656
# 87       Italy                  2211                509
# 178     Sweden                  1738                456
# 39       China                  1423                381
# 33      Canada                  2113                363
# 10   Australia                  1846                355

# %%
#plot for players count
plt.figure(figsize=(18,8))
plt.suptitle('No of Players Participated and Medal won in Top 10 Country')
plt.subplot(1,2,1)
sns.barplot(data=at10,x='Country',y='Participated_Players',palette='flare')
plt.xticks(rotation='vertical')
plt.subplot(1,2,2)
sns.barplot(data=at10,x='Country',y='Medal_Won_Players',palette='crest')
plt.xticks(rotation='vertical')
plt.show()

# %%
#bar plot b/w participated and medal won players
plt.figure(figsize=(10,6))
plt.title('No of Paticipated Players vs No of Medal Won Players')
plt.bar(x='Country',height='Participated_Players',data=at10,label='Participated_Players')
plt.bar(x='Country',height='Medal_Won_Players',data=at10,label='Medal_Won_Players')
plt.legend(['Participated_Players','Medal_Won_Players'])
plt.show()

# %%
#creating pivot for medal count
ap=above18.pivot_table(index=['Country'],values='Medal',aggfunc='count')
#country with medals
ap=ap[ap.Medal!=0]
#pivot table
ap
# Out:
#                     Medal
# Country
# Afghanistan             2
# Algeria                17
# Argentina              74
# Armenia                16
# Australia             494
# ...                   ...
# Venezuela              15
# Vietnam                 4
# Virgin Islands, US      1
# Zambia                  2
# Zimbabwe                8
#
# [137 rows x 1 columns]

# %%
#max medal won 10 country
ap10m=ap.nlargest(10,'Medal')
ap10m
# Out:
#            Medal
# Country
# USA         2653
# Russia      1862
# Germany     1686
# UK           899
# France       866
# Italy        713
# Sweden       648
# China        554
# Australia    494
# Hungary      494

# %%
#bar plot for pivot
plt.figure(figsize=(8,5))
ax=sns.barplot(y='Medal',data=ap10m,x=ap10m.index)
plt.title("Top 10 Countries and their Medal Count for above 18 year players")
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+1,round(rect.get_height()),horizontalalignment='center',fontsize=11)
plt.show()

# %%
#creating pivot for medal count
apv=above18.pivot_table(index=['Country','Games'],values='Medal',aggfunc='count')
#non-zero medal rows only
#country with game season and medal count
apv=apv[apv.Medal!=0]
#pivot
apv
# Out:
#                          Medal
# Country     Games
# Afghanistan 2008 Summer      1
#             2012 Summer      1
# Algeria     1984 Summer      2
#             1992 Summer      2
#             1996 Summer      3
# ...                        ...
# Zambia      1984 Summer      1
#             1996 Summer      1
# Zimbabwe    1980 Summer      1
#             2004 Summer      3
#             2008 Summer      4
#
# [1640 rows x 1 columns]

# %%
#max medal won 10 country
apv.nlargest(10,'Medal')
# Out:
#                      Medal
# Country Games
# USA     1904 Summer    226
# Russia  1980 Summer    190
# USA     1984 Summer    163
# UK      1908 Summer    143
# Germany 1988 Summer    137
# Russia  1988 Summer    125
#         1976 Summer    121
# USA     2016 Summer    120
# Germany 1976 Summer    113
# USA     1932 Summer    106

# %% [markdown]
# Some Max and Min observations

# %%
#eldeset person age
data.Age.max()
# Out:
# 97.0

# %%
#eldest person who participated in olympics
data[data.Age==data.Age.max()]
# Out:
#                           Name Sex   Age  Height  Weight        Games  Year  \
# ID
# 128719  John Quincy Adams Ward   M  97.0   175.0    71.0  1928 Summer  1928
#
#         Season       City             Sport  \
# ID
# 128719  Summer  Amsterdam  Art Competitions
#
#                                               Event Medal Country
# ID
# 128719  Art Competitions Mixed Sculpturing, Statues   NaN     USA

# %%
#john quincy adams ward is not alive when he won the medal
#so the oldest person is, (as per oldeest.org)
data.loc[22984]
# Out:
#                                                 Name Sex   Age  Height  \
# ID
# 22984  John (Herbert Crawford-) Copley (Williamson-)   M  73.0   175.0
# 22984  John (Herbert Crawford-) Copley (Williamson-)   M  73.0   175.0
#
#        Weight        Games  Year  Season    City             Sport  \
# ID
# 22984    71.0  1948 Summer  1948  Summer  London  Art Competitions
# 22984    71.0  1948 Summer  1948  Summer  London  Art Competitions
#
#                                                Event   Medal Country
# ID
# 22984  Art Competitions Mixed Painting, Graphic Arts  Silver      UK
# 22984     Art Competitions Mixed Painting, Paintings     NaN      UK

# %%
#youngest person age
data.Age.min()
# Out:
# 10.0

# %%
#youngest person who participated in olympics
data[data.Age==data.Age.min()]
# Out:
#                      Name Sex   Age  Height  Weight        Games  Year  \
# ID
# 71691  Dimitrios Loundras   M  10.0   175.0    71.0  1896 Summer  1896
#
#        Season    City       Sport                                  Event  \
# ID
# 71691  Summer  Athina  Gymnastics  Gymnastics Men's Parallel Bars, Teams
#
#         Medal Country
# ID
# 71691  Bronze  Greece

# %%
#tallest persons's height
data.Height.max()
# Out:
# 226.0

# %%
#tallest person who participated in olympics
data[data.Height==data.Height.max()]
# Out:
#             Name Sex   Age  Height  Weight        Games  Year  Season  \
# ID
# 132627  Yao Ming   M  20.0   226.0   141.0  2000 Summer  2000  Summer
# 132627  Yao Ming   M  23.0   226.0   141.0  2004 Summer  2004  Summer
# 132627  Yao Ming   M  27.0   226.0   141.0  2008 Summer  2008  Summer
#
#            City       Sport                        Event Medal Country
# ID
# 132627   Sydney  Basketball  Basketball Men's Basketball   NaN   China
# 132627   Athina  Basketball  Basketball Men's Basketball   NaN   China
# 132627  Beijing  Basketball  Basketball Men's Basketball   NaN   China

# %%
#heaviest person's weight
data.Weight.max()
# Out:
# 214.0

# %%
#weightest person who participated in olympics
data[data.Weight==data.Weight.max()]
# Out:
#                     Name Sex   Age  Height  Weight        Games  Year  Season  \
# ID
# 12177  Ricardo Blas, Jr.   M  21.0   183.0   214.0  2008 Summer  2008  Summer
# 12177  Ricardo Blas, Jr.   M  25.0   183.0   214.0  2012 Summer  2012  Summer
#
#           City Sport                   Event Medal Country
# ID
# 12177  Beijing  Judo  Judo Men's Heavyweight   NaN    Guam
# 12177   London  Judo  Judo Men's Heavyweight   NaN    Guam

# %% [markdown]
# ## India's Data

# %%
#lets see our country data
ind=data[data.Country=='India']
ind
# Out:
#                                                  Name Sex   Age  Height  \
# ID
# 281                                    S. Abdul Hamid   M  25.0   175.0
# 281                                    S. Abdul Hamid   M  25.0   175.0
# 512                   Shiny Kurisingal Abraham-Wilson   F  19.0   167.0
# 512                   Shiny Kurisingal Abraham-Wilson   F  19.0   167.0
# 512                   Shiny Kurisingal Abraham-Wilson   F  23.0   167.0
# ...                                               ...  ..   ...     ...
# 132177                           Mohammad Anas Yahiya   M  21.0   177.0
# 133029  Thyadathuvilla Chandrapillai "T. C." Yohannan   M  29.0   174.0
# 133554                           Sayed Muhammad Yusuf   M  25.0   175.0
# 135480                                   Geeta Zutshi   F  23.0   167.0
# 135480                                   Geeta Zutshi   F  27.0   167.0
#
#         Weight        Games  Year  Season            City      Sport  \
# ID
# ...

# %%
#india participated in these years
iy=ind.Year.unique()
iy=np.sort(iy)
iy
# Out:
# array([1900, 1920, 1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964,
#        1968, 1972, 1976, 1980, 1984, 1988, 1992, 1996, 1998, 2000, 2002,
#        2004, 2006, 2008, 2010, 2012, 2014, 2016], dtype=int64)

# %%
#india participated in these seasons
gmi=ind.Games.unique()
gmi=np.sort(gmi)
gmi
# Out:
# array(['1900 Summer', '1920 Summer', '1924 Summer', '1924 Winter',
#        '1928 Summer', '1932 Summer', '1936 Summer', '1948 Summer',
#        '1952 Summer', '1956 Summer', '1960 Summer', '1964 Summer',
#        '1964 Winter', '1968 Summer', '1968 Winter', '1972 Summer',
#        '1976 Summer', '1980 Summer', '1984 Summer', '1988 Summer',
#        '1988 Winter', '1992 Summer', '1992 Winter', '1996 Summer',
#        '1998 Winter', '2000 Summer', '2002 Winter', '2004 Summer',
#        '2006 Winter', '2008 Summer', '2010 Winter', '2012 Summer',
#        '2014 Winter', '2016 Summer'], dtype=object)

# %%
#count of seasons india participated
len(gmi)
# Out:
# 34

# %%
#lets find no of playes participated for india in season wise
noi=[]
no_m=[]
no_f=[]
for i in gmi:
    noi.append(ind[ind.Games==i].index.nunique())
    no_m.append(ind[(ind.Sex=='M')&(ind.Games==i)].index.nunique())
    no_f.append(ind[(ind.Sex=='F')&(ind.Games==i)].index.nunique())
#putting into dataframe
ind_player=pd.DataFrame(list(zip(gmi,noi,no_m,no_f)),columns=['Game','Total_Players','Male','Female'])
ind_player
# Out:
#            Game  Total_Players  Male  Female
# 0   1900 Summer              1     1       0
# 1   1920 Summer              5     5       0
# 2   1924 Summer             13    12       1
# 3   1924 Winter              7     7       0
# 4   1928 Summer             21    21       0
# ..          ...            ...   ...     ...
# 29  2008 Summer             53    31      22
# 30  2010 Winter              3     3       0
# 31  2012 Summer             81    58      23
# 32  2014 Winter              2     2       0
# 33  2016 Summer            112    61      51
#
# [34 rows x 4 columns]

# %%
#plot a graph for players count on each season
plt.figure(figsize=(15,8))
plt.title('No of Players for each Season')
ax=sns.barplot(x='Game',y='Total_Players',data=ind_player)
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+0.5,rect.get_height(),horizontalalignment='center',fontsize=11)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# from the graph we can see india participate maximum in summer games

# %%
#india participated in these sports
spi=ind.Sport.unique()
spi=np.sort(spi)
spi
# Out:
# array(['Alpine Skiing', 'Alpinism', 'Archery', 'Art Competitions',
#        'Athletics', 'Badminton', 'Basketball', 'Boxing',
#        'Cross Country Skiing', 'Cycling', 'Diving', 'Equestrianism',
#        'Football', 'Golf', 'Gymnastics', 'Hockey', 'Judo', 'Luge',
#        'Rowing', 'Sailing', 'Shooting', 'Swimming', 'Table Tennis',
#        'Tennis', 'Water Polo', 'Weightlifting', 'Wrestling'], dtype=object)

# %%
#count of sports
len(spi)
# Out:
# 27

# %%
#lets find no of playes participated for india in season wise
noi=[]
no_m=[]
no_f=[]
for i in spi:
    noi.append(ind[ind.Sport==i].index.nunique())
    no_m.append(ind[(ind.Sex=='M')&(ind.Sport==i)].index.nunique())
    no_f.append(ind[(ind.Sex=='F')&(ind.Sport==i)].index.nunique())
#putting into dataframe
ind_player_sp=pd.DataFrame(list(zip(spi,noi,no_m,no_f)),columns=['Sport','Total_Players','Male','Female'])
ind_player_sp
# Out:
#                Sport  Total_Players  Male  Female
# 0      Alpine Skiing             10     8       2
# 1           Alpinism              7     7       0
# 2            Archery             21    13       8
# 3   Art Competitions              2     2       0
# 4          Athletics            172   119      53
# ..               ...            ...   ...     ...
# 22      Table Tennis             13     6       7
# 23            Tennis             21    14       7
# 24        Water Polo             17    17       0
# 25     Weightlifting             30    25       5
# 26         Wrestling             78    74       4
#
# [27 rows x 4 columns]

# %%
#plot a graph for players count on each sports
plt.figure(figsize=(15,8))
plt.title('No of Players for each Sport')
ax=sns.barplot('Sport','Total_Players',data=ind_player_sp)
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+0.5,rect.get_height(),horizontalalignment='center',fontsize=11)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# from the graph we can see india participate maximum in hockey and athletics

# %%
#no of medal india got
md[md.index=='India']
# Out:
#          Medal
# Country
# India       29

# %%
#india's medal count with its type
imc=mtc[mtc.Country=='India']
imc=imc.sort_values(by='Medal_count',ascending=False)
imc
# Out:
#     Country   Medal  Medal_count
# 121   India  Bronze           12
# 122   India    Gold           10
# 123   India  Silver            7

# %%
#india's medal count
plt.figure(figsize=(10,7))
ax=sns.barplot(data=imc,x='Medal',y='Medal_count')
plt.title("India's Medal Count till 2016")
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+0.1,rect.get_height(),horizontalalignment='center',fontsize=12)
plt.show()

# %%
#plot for indian player medal count with gender wise
countplot, ax=plt.subplots(figsize=(10,7))
sns.countplot(data=ind,x='Sex',hue='Medal')
ax.set_title("India's Medal count by Gender")
ax.set_ylabel('Count of Medal')
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+1,rect.get_height(),horizontalalignment='center',fontsize=11)
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
#india's medal count with season
in_medal=mc.loc['India']
in_medal.reset_index(inplace=True)
in_medal
# Out:
#           Games  Medal_count
# 0   1900 Summer            2
# 1   1924 Winter            1
# 2   1928 Summer            1
# 3   1932 Summer            1
# 4   1936 Summer            1
# ..          ...          ...
# 14  2000 Summer            1
# 15  2004 Summer            1
# 16  2008 Summer            3
# 17  2012 Summer            6
# 18  2016 Summer            2
#
# [19 rows x 2 columns]

# %%
#india's maximum medal 
in_medal.nlargest(1,'Medal_count')
# Out:
#           Games  Medal_count
# 17  2012 Summer            6

# %%
#lineplot for india's medal count over years
plt.figure(figsize=(18,8))
g=sns.lineplot(data=in_medal,x='Games',y='Medal_count',markers=True)
g.set_xticklabels(labels=in_medal.Games,rotation=90)
g.set_title("India's Medal Count over Years")
plt.show()

# %%
#bar chart for the india's medal count
plt.figure(figsize=(12,6))
plt.title("India's Medal Count with Season")
ax=sns.barplot(data=in_medal,x='Games',y='Medal_count')
plt.xticks(rotation='vertical')
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+0.1,rect.get_height(),horizontalalignment='center',fontsize=11)
plt.show()

# %%
#lets see our country medal list with season and type of medal
cm.loc['India']
# Out:
#                     Medal_count
# Games       Medal
# 1900 Summer Silver            2
# 1924 Winter Gold              1
# 1928 Summer Gold              1
# 1932 Summer Gold              1
# 1936 Summer Gold              1
# ...                         ...
# 2008 Summer Gold              1
# 2012 Summer Bronze            4
#             Silver            2
# 2016 Summer Bronze            1
#             Silver            1
#
# [23 rows x 1 columns]

# %%
#lets see our country medal list with sport wise
ins=ms.loc['India']
ins=ins.sort_values(by='Medal_count',ascending=False)
ins.reset_index(inplace=True)
ins
# Out:
#            Sport  Medal_count
# 0         Hockey           11
# 1      Wrestling            5
# 2       Shooting            4
# 3      Athletics            2
# 4      Badminton            2
# 5         Boxing            2
# 6       Alpinism            1
# 7         Tennis            1
# 8  Weightlifting            1

# %%
#bar chart for the india's medal count
plt.figure(figsize=(10,5))
ax=sns.barplot(data=ins,x='Sport',y='Medal_count')
plt.title("India's Medal Count with Sport")
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+0.1,round(rect.get_height(),0),horizontalalignment='center',fontsize=11)
plt.show()

# %%
#indian players who got medal
ind['Medal1']=ind.Medal
inmc=ind.pivot_table(index=['Name','Sport','Medal'],values='Medal1',aggfunc='count')
inmc=inmc.rename(columns={'Medal1':'Medal_count'})
inmc
# Out:
#                                                         Medal_count
# Name                                  Sport     Medal
# Abhinav Bindra                        Shooting  Gold              1
# Ahmed Sher Khan                       Hockey    Gold              1
# Ahsan Muhammad Khan                   Hockey    Gold              1
# Ajitpal Singh Kular                   Hockey    Bronze            2
# Akhtar Hussain                        Hockey    Gold              1
# ...                                                             ...
# Walter Louis Joseph de Sousa          Hockey    Gold              1
# William James "Willie" Goodsir-Cullen Hockey    Gold              1
# William Patrick "Pat" Sullivan        Hockey    Gold              1
# Yogeshwar Dutt                        Wrestling Bronze            1
# Zafar Iqbal                           Hockey    Gold              1
#
# [163 rows x 1 columns]

# %%
#maximum medal won persons (top 10)
inmc.nlargest(10,'Medal_count')
# Out:
#                                          Medal_count
# Name                      Sport  Medal
# Balbir Singh              Hockey Bronze            3
# Balbir Singh Dosanjh, Sr. Hockey Gold              3
# Dhyan Chand Bais          Hockey Gold              3
# Leslie Walter Claudius    Hockey Gold              3
# Randhir Singh Gentle      Hockey Gold              3
# Ranganathan Francis       Hockey Gold              3
# Richard James Allen       Hockey Gold              3
# Udham Singh Kular         Hockey Gold              3
# Ajitpal Singh Kular       Hockey Bronze            2
# Amir Chand Kumar          Hockey Gold              2

# %% [markdown]
# ## India's Hockey game details

# %%
#lets take india's performance in hockey
ih=ind[ind.Sport=='Hockey']
ih
# Out:
#                                 Name Sex   Age  Height  Weight        Games  \
# ID
# 1415                   Shakeel Ahmed   M  21.0   175.0    71.0  1992 Summer
# 2453           Anil Alexander Aldrin   M  24.0   175.0    71.0  1996 Summer
# 2699                     Shaukat Ali   M  30.0   175.0    71.0  1928 Summer
# 2702                        Syed Ali   M  19.0   169.0    60.0  1976 Summer
# 2703                Syed Mushtaq Ali   M  22.0   165.0    61.0  1964 Summer
# ...                              ...  ..   ...     ...     ...          ...
# 126867  Sunil Sowmarpet Vitalacharya   M  27.0   176.0    68.0  2016 Summer
# 128249        Devindar Sunil Walmiki   M  24.0   178.0    69.0  2016 Summer
# 131974                 William Xalco   M  20.0   167.0    60.0  2004 Summer
# 132142                  Renuka Yadav   F  22.0   159.0    53.0  2016 Summer
# 133554          Sayed Muhammad Yusuf   M  25.0   175.0    71.0  1928 Summer
#
# ...

# %%
#partcipated players till 2016
noi=ih.index.nunique()
no_m=ih[ih.Sex=='M'].index.nunique()
no_f=ih[ih.Sex=='F'].index.nunique()
x={'Total_Participated_Players':noi,'Male':no_m,'Female':no_f}
ihp=pd.DataFrame(x,index=['Hockey'])
ihp
# Out:
#         Total_Participated_Players  Male  Female
# Hockey                         256   226      30

# %%
#medal won players till 2016
noi=ih[~ih.Medal.isnull()].index.nunique()
no_m=ih[(ih.Sex=='M') & (~ih.Medal.isnull())].index.nunique()
no_f=ih[(ih.Sex=='F') & (~ih.Medal.isnull())].index.nunique()
x={'Medal_Won_Players':noi,'Male':no_m,'Female':no_f}
ihpw=pd.DataFrame(x,index=['Hockey'])
ihpw
# Out:
#         Medal_Won_Players  Male  Female
# Hockey                128   128       0

# %%
#dropping duplicates for team medal count
ih.drop_duplicates(subset=['Games','Year','Season','City','Sport','Event','Medal','Country'],inplace=True)

# %%
#finding medal count season wise
ihm=ih.pivot_table(index=['Games'],values='Medal',aggfunc='count')
ihm=ihm[ihm.Medal!=0]
ihm=ihm.sort_values(by='Medal')
ihm
# Out:
#              Medal
# Games
# 1928 Summer      1
# 1932 Summer      1
# 1936 Summer      1
# 1948 Summer      1
# 1952 Summer      1
# ...            ...
# 1960 Summer      1
# 1964 Summer      1
# 1968 Summer      1
# 1972 Summer      1
# 1980 Summer      1
#
# [11 rows x 1 columns]

# %% [markdown]
# ## India's 2016 performance

# %%
#india's 2016 data
in16=ind[ind.Year==2016]
in16
# Out:
#                           Name Sex   Age  Height  Weight        Games  Year  \
# ID
# 663      Sharath Kamal Achanta   M  34.0   186.0    85.0  2016 Summer  2016
# 4523               Seema Antil   F  33.0   182.0    92.0  2016 Summer  2016
# 5562               Aditi Ashok   F  18.0   173.0    57.0  2016 Summer  2016
# 5868                Manu Attri   M  23.0   172.0    73.0  2016 Summer  2016
# 6427      Lalita Shivaji Babar   F  27.0   166.0    50.0  2016 Summer  2016
# ...                        ...  ..   ...     ...     ...          ...   ...
# 128249  Devindar Sunil Walmiki   M  24.0   178.0    69.0  2016 Summer  2016
# 132142            Renuka Yadav   F  22.0   159.0    53.0  2016 Summer  2016
# 132143     Vikas Krishan Yadav   M  24.0   177.0    69.0  2016 Summer  2016
# 132177    Mohammad Anas Yahiya   M  21.0   177.0    69.0  2016 Summer  2016
# 132177    Mohammad Anas Yahiya   M  21.0   177.0    69.0  2016 Summer  2016
#
#         Season            City         Sport  \
# ...

# %%
#total no of players participated in 2016 olympics
n=in16.index.nunique()
m=in16[in16.Sex=='M'].index.nunique()
f=in16[in16.Sex=='F'].index.nunique()
d=[{'Total_Players':n,'Male':m,'Female':f}]
pd.DataFrame(d,index=[2016])
# Out:
#       Total_Players  Male  Female
# 2016            112    61      51

# %%
#india participated sports in 2016
in16.Sport.unique()
# Out:
# array(['Table Tennis', 'Athletics', 'Golf', 'Badminton', 'Wrestling',
#        'Rowing', 'Shooting', 'Tennis', 'Archery', 'Hockey', 'Gymnastics',
#        'Swimming', 'Boxing', 'Weightlifting', 'Judo'], dtype=object)

# %%
#india participated events in 2016
pd.DataFrame(in16.Event.unique())
# Out:
#                                               0
# 0                    Table Tennis Men's Singles
# 1                Athletics Women's Discus Throw
# 2                       Golf Women's Individual
# 3                       Badminton Men's Doubles
# 4   Athletics Women's 3,000 metres Steeplechase
# ..                                          ...
# 62             Weightlifting Men's Middleweight
# 63                    Boxing Men's Bantamweight
# 64     Wrestling Men's Featherweight, Freestyle
# 65                    Boxing Men's Middleweight
# 66                   Athletics Men's 400 metres
#
# [67 rows x 1 columns]

# %%
#their medal counts
in16['Medal1']=in16.Medal
in16pv=pd.pivot_table(in16,index=['Sport','Sex','Medal'],values='Medal1',aggfunc='count')
in16pv=in16pv.rename(columns={'Medal1':'Medal_count'})
in16.drop(columns='Medal1',axis=1,inplace=True)
in16pv
# Out:
#                       Medal_count
# Sport     Sex Medal
# Badminton F   Silver            1
# Wrestling F   Bronze            1

# %%
#two players who got medal in 2016 olympics
in16[~in16.Medal.isnull()]
# Out:
#                                   Name Sex   Age  Height  Weight        Games  \
# ID
# 74069                     Sakshi Malik   F  23.0   162.0    58.0  2016 Summer
# 110974  Pusarla Venkata "P. V." Sindhu   F  21.0   179.0    65.0  2016 Summer
#
#         Year  Season            City      Sport  \
# ID
# 74069   2016  Summer  Rio de Janeiro  Wrestling
# 110974  2016  Summer  Rio de Janeiro  Badminton
#
#                                            Event   Medal Country
# ID
# 74069   Wrestling Women's Lightweight, Freestyle  Bronze   India
# 110974                 Badminton Women's Singles  Silver   India
